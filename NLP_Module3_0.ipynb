# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajat504/CLOUDYML/blob/main/NLP_Module3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center><u> <h1>NLP Assignment-1_Introduction to NLP</h1></u></center>
#
# ---
# **Topics covered to this Assignment:**
#
# *   Introduction to NLP
# *   Basics of NLP
#     1. Tokenization
#     2.Lemmatization
#     3. Stemming
#     4. How to remove stop words
# ---
#
# ![image11.png](https://d1m75rqqgidzqn.cloudfront.net/wp-data/2021/01/18170655/an-introduction-to-natural-language-processing-with-python-for-seos-5f3519eeb8368.png)

# %% [markdown]
# ## What is NLP?
#
# Natural language processing (NLP) is a field of artificial intelligence in which computers analyze, understand, and derive meaning from human language in a smart and useful way.
#
# ![image14.jpg](https://static.wixstatic.com/media/40af5e_79b8958ea7bb4a2f93a3e5617e821345~mv2.png/v1/fill/w_730,h_193,al_c,q_95/40af5e_79b8958ea7bb4a2f93a3e5617e821345~mv2.webp)
#
# <br>
# It is a discipline that focuses on the interaction between data science and human language, and is scaling to lots of industries. Today NLP is booming thanks to the huge improvements in the access to data and the increase in computational power, which are allowing practitioners to achieve meaningful results in areas like healthcare, media, finance and human resources, among others.
#
# Do refer this amazing video to know what is NLP in an interesting way.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Hbx9bxt7gvc', width=600, height=300)

# %% [markdown]
# ## Applications of NLP in the industry
#
# Natural Language Processing technology is especially valuable for businesses. A number of companies have already taken advantage of NLP services from Unicsoft to gain a competitive edge over their rivals.
#
# Firstly, this technology helps derive understanding from the multiple unstructured data available online and in call logs. Next, since businesses feel the constant need for enhancing the communication process with their customers, NLP tools are the best way to improve the quality of this interaction. Application of NLP can be found in a range of business contexts, including e-commerce, healthcare and advertising.
#
# ![image13.png](https://lh3.googleusercontent.com/rQFuLPs6YeZJIcUpz_ECbNZiS58kdLfhA8uIBtqOsXGrjC6iMs-xt7xgeE0IhO_15WPFfn36Ngj2Mzbe-6aQEIYohO8l40unPALjWHJtXsjwE7f27-GS9UgxiZgyz7p9_uSf0d98=s0)
#
# ## Here are the top NLP use cases in business.
#
# #### 1. Machine Translation
# #### 2. Social Media Monitoring
# #### 3. Sentiment Analysis
# #### 4. Chatbots and Virtual Assistants
# #### 5. Text analysis
# #### 6. Speech Recognition
# #### 7. Text Extraction
# #### 8. Autocorrect, Spell Check

# %%
###### Refer video:
YouTubeVideo('6Eekv-pZfHY', width=600, height=300)

# %% [markdown]
# # Basics of NLP
# 1. Tokenization
# 2. Lemmatization
# 3. Stemming
# 4. How to remove stop words

# %% [markdown]
#   # Tokenization
# Probably the first thing most NLP algorithms have to do is to split the text into tokens, or words. While this sounds simple, having to account for punctuation and different languages word and sentence delimiters can make it tricky. You might have to use various methods to determine demarcations.
#
# ![1_token.png](data:image/png;base64,...)
#
#
#
# Documentation link: [https://docs.python.org/3/library/tokenize.html](https://)

# %%
###### Refer video:
YouTubeVideo('Dh4El5MtxpE', width=600, height=300)

# %% [markdown]
# ---
#
#
# ### In this assignment, you'll learn about the Tokenization,Lemmatization,Stemming and How to remove stop words etc.
#
# First, We will see about tokenization technique in nlp.
#
# Now, let's import the **NLTK Library** and download the **PUNKT** package for tokenization.
#
# ---

# %% [markdown]
# #### Punkt:<br>
# This tokenizer divides a text into a list of sentences
# by using an unsupervised algorithm to build a model for abbreviation
# words, collocations, and words that start sentences.  It must be
# trained on a large collection of plaintext in the target language
# before it can be used.
#
#  Punkt Documentation:
#  [Punkt](https://www.nltk.org/_modules/nltk/tokenize/punkt.html)

# %%
#Tokenization of paragraphs and press q for download
#Import nltk and nltk.download(punkt)  [enter q in input box]
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
#  **So further we are go to Take Paragraph as input variable and we will Tokenize the paragraph into sentences and words respectively.**

# %%
#Run this cell for storing input paragraph into one variable
paragraph = '''Welcome to CloudyML. Hands-on of every thing you need to know about Cloud & Machine Learning and how we can combine both to build very powerful applications.'''

# %% [markdown]
# In the next cell,<br>
# the paragraph is converted into sentences and  sent_tokenize method from the nltk library is used to tokenize sentences

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

paragraph = '''Welcome to CloudyML. Hands-on of every thing you need to know about Cloud & Machine Learning and how we can combine both to build very powerful applications.'''

sentences = nltk.sent_tokenize(paragraph)

print(sentences)
# Out:
# ['Welcome to CloudyML.', 'Hands-on of every thing you need to know about Cloud & Machine Learning and how we can combine both to build very powerful applications.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# Tokenizing sentences using nltk.sent_tokenize
#(converting paragraphs into sentences)
nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# ['Welcome to CloudyML.', 'Hands-on of every thing you need to know about Cloud & Machine Learning and how we can combine both to build very powerful applications.']

# %% [markdown]
# As we can see that the paragraph is tokenized with sentences by using nltk.<br>
# So you aslo try with your inputs by changing the input variables paragraph :)

# %% [markdown]
# For next cell,<br>
# The paragraph is converted into words and word_tokenize method from the nltk library is used to tokenize words.

# %%
# Tokenizing words using nltk.word_tokenize
#(converting paragraphs into words)
words = nltk.word_tokenize(paragraph)
print(words)
# Out:
# ['Welcome', 'to', 'CloudyML', '.', 'Hands-on', 'of', 'every', 'thing', 'you', 'need', 'to', 'know', 'about', 'Cloud', '&', 'Machine', 'Learning', 'and', 'how', 'we', 'can', 'combine', 'both', 'to', 'build', 'very', 'powerful', 'applications', '.']

# %% [markdown]
# As per observation on output we can see that the input is tokenized with words.
#
# <br>
#
#  **For better understanding of tokeinzation with sentences and words try to play with your inputs :))**
# ---

# %% [markdown]
# # **Lemmatization**
#
# It is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item.
# It is similar to stemming but it brings context to the words. So it links words with similar meanings to one word.
# ![2_lemma.png](data:image/png;base64,...)
#
#
# **Applications of lemmatization are:**
#
# Used in comprehensive retrieval systems like search engines and compact indexing
#
# Documentation :  https://www.kite.com/python/docs/nltk.WordNetLemmatizer

# %%
###### Refer video:
YouTubeVideo('JpxCt3kvbLk', width=600, height=300)

# %% [markdown]
# ---
# ### Same as Tokenization here we aslo include nltk Library and download the package for lemmatization.
#
# In Nlp, We have to download the neccessary packages using download function.<br>
# In Lemmatization, We use wordnet package and will download the package by using nltk.download('wordnet')

# %% [markdown]
# ---
#
# **WordNet** is a database of words, synonyms, antonyms and many other details for every word in many different languages. It is incredibly useful when attempting to build translations, spell checkers, or language tools of any type.
#
# Reference: https://www.nltk.org/howto/wordnet.html

# %%
# import nltk module
# from nltk.stem import WordNetLemmatizer and download wordnet
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# For Next cell,<br>
# 1. lemmatizer(any name can be chosen) object of the WordNetLemmatizer class is created as object is an instance of the class that can implement all the methods and functionalities of the class.
# 2. lemmatize method of the WordNetLemmatizer class is called by the 'lemmatizer' object to lemmatize the given words.

# %%
#create Wordnetlemmatizer object
#lemmatize the given words or you can use your own words :)
#lemmatizer=WordNetLemmarizer()
#print("rocks :", lemmatizer.lemmatize("rocks"))
lemmatizer=nltk.stem.WordNetLemmatizer()
print("rocks :", lemmatizer.lemmatize("rocks"))
print("corpora :", lemmatizer.lemmatize("corpora"))
# Out:
# rocks : rock
# corpora : corpus

# %% [markdown]
# As per the output shown, The word Rocks is lemmitize to Rock.

# %% [markdown]
# # **Stemming**
#
# It is the process of producing morphological variants of a root/base word. Stemming programs are commonly referred to as stemming algorithms or stemmers. A stemming algorithm reduces the words “chocolates”, “chocolatey”, “choco” to the root word, “chocolate” and “retrieval”, “retrieved”, “retrieves” reduce to the stem “retrieve”. Stemming is an important part of the pipelining process in Natural language processing. The input to the stemmer is tokenized words.
#
# ![4_Stemming.jpeg](data:image/jpeg;base64,...)
#
# Applications of stemming :
# 1.  Stemming is used in information retrieval systems like search engines.
# 2.  It is used to determine domain vocabularies in domain analysis.

# %% [markdown]
# ---
# Same as above we are going importing nltk and porterstemmer for stemming
#
# ---

# %% [markdown]
# The Porter stemming algorithm (or 'Porter stemmer') is a process for removing the commoner morphological and inflexional endings from words in English. Its main use is as part of a term normalisation process that is usually done when setting up Information Retrieval systems.
#
# Reference: https://www.nltk.org/_modules/nltk/stem/porter.html

# %%
# import these modules
# from nltk.stem import porterstemmer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %% [markdown]
# In the next cell,<br>
# ps(any name can be chosen) object of the PorterStemmer class is created as object is an instance of the class that can implement all the methods and functionalities of the class.

# %%
# Create PorterStemmer Object
ps = PorterStemmer()

# %% [markdown]
# Stem method of the PorterStemmer class is called by the 'ps' object to stem the given words.

# %%
#choose some words to be stemmed
words = ["program", "programs", "programmer", "programming", "programmers"]

#use for loop to iterate words
for w in words:
    print(w, " : ", ps.stem(w))


# stem method of the PorterStemmer class is called by the 'ps' object to stem the given words.
programs: program
programmer: program
programming: program
programmers: programmer
# Out:
# program  :  program
# programs  :  program
# programmer  :  programm
# programming  :  program
# programmers  :  programm
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1d182d2c3b1f> in <cell line: 0>()
#       8
#       9 # stem method of the PorterStemmer class is called by the 'ps' object to stem the given words.
# ---> 10 programs: program
#      11 programmer: program
#      12 programming: program
#
# NameError: name 'program' is not defined

# %% [markdown]
# As we can that the various words of programs is stemmed into program.
# Try to play with words in code for better understanding ;)
# ---

# %% [markdown]
# ##Stemming VS Lemmatization
#
# **Stemming** just removes or stems the last few characters of a word, often leading to incorrect meanings and spelling.<br>
# <br>
# **Lemmatization** considers the context and converts the word to its meaningful base form, which is called Lemma. Sometimes, the same word can have multiple different Lemmas.
#
#
#
# ![stemm vs lemmatization.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # How to remove stop words
# The stopwords in nltk are the most common words in data. They are words that you do not want to use to describe the topic of your content. They are pre-defined and cannot be removed.
#
# ![image24.png](https://www.askpython.com/wp-content/uploads/2020/11/stop-words-1024x512.png.webp)
#
# Documtation: https://pythonspot.com/nltk-stop-words/

# %%
###### Refer video:
YouTubeVideo('ob6IlbV13IM', width=600, height=300)

# %%
#import nltk and download nltk stopwords
import nltk
from nltk.corpus import stopwords
from IPython.display import YouTubeVideo
#nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ---
# Further, English stopwords are loaded using the 'words' method from the stopwords class.
#
# ---

# %%
#importing Stop words
#from nltk.corpus import stopwords #stopwords.words('english') from nltk.corpus import stopwords stopwords.words('english')
import nltk
from nltk.corpus import stopwords

# Download the 'stopwords' dataset
nltk.download('stopwords')

# Now you can use stopwords.words('english')
stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
# ...

# %% [markdown]
# In the next Cell,
# english stopwords are loaded into the *en_stops* variable using the set function

# %%
#Checking Stops words in a sentences
#example of Stopwords
#you can try with your inputs :)
en_stops = set(stopwords.words('english'))
words = ['There', 'is', 'a', 'Deep','Learning','Course','in','CLoudyML']
for word in words:
    if word not in en_stops:
        print(word)
# Out:
# There
# Deep
# Learning
# Course
# CLoudyML

# %% [markdown]
# So as we can see that 'is', 'a' , 'in' is removed because they are stopswords.

# %% [markdown]
# As we covered many basics topics in NLP. Now you will able to use many basics techniques in NLP for operaions such as tokenization,stemming etc
# ---

# %% [markdown]
# Great job!! You have come to the end of this practice sheet. Treat yourself for this :))
# <br>
# # Do fill this [feedback form](https://forms.zohopublic.in/cloudyml/form/CloudyMLDeepLearningFeedbackForm/formperma/VCFbldnXAnbcgAIl0lWv2blgHdSldheO4RfktMdgK7s)
# <br>
# You may head on to the next assignment.

# %% [markdown]
# ![](https://i.pinimg.com/736x/58/a6/11/58a61190235ae27c0a51f79941b0bcea.jpg)

# %% [markdown]
# For getting better understanding of NlP try with your inputs and words ;)
# ---
